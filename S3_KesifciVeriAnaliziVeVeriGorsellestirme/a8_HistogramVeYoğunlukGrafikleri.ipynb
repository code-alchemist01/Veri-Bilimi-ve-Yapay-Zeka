# %% [markdown]
# # Hİstogram Ve Yoğunluk Grafikleri

# %% [markdown]
# * 1. Histogram (histplot)
# Histogram, sayısal verinin belirli aralıklara (bin'lere) bölünüp, her aralıkta kaç gözlem olduğunu gösteren bir grafiktir.
#
# > 📌 Özellikler:
# * ✔ Sayısal değişkenlerin dağılımını gösterir.
# * ✔ X ekseni veri değerlerini, Y ekseni frekansı (kaç tane olduğunu) gösterir.
# * ✔ Bin sayısı artırılıp azaltılabilir (bins parametresi ile).
# * bins=20 → Histogramın 20 farklı aralığa bölünmesini sağlar.
# * kde=True → Histogramın üzerine yoğunluk eğrisi çizer.
#
# * 2. Yoğunluk Grafiği (kdeplot)
# Yoğunluk grafiği (KDE - Kernel Density Estimation), histogramın daha düzgün ve sürekli bir versiyonudur. Bir değişkenin olasılık yoğunluk fonksiyonunu tahmin eder.
#
# > 📌 Özellikler:
# * ✔ Histogramdan daha pürüzsüzdür ve sürekli bir eğri gösterir.
# * ✔ Verinin dağılım şeklini daha iyi görselleştirir.
# * ✔ Çeşitli kernel fonksiyonları ile özelleştirilebilir.
# * fill=True → Alanın dolu olmasını sağlar (standart KDE eğrisi çizgi olarak da bırakılabilir).
#
# * 3. displot: Histogram ve Yoğunluk Grafiği Birleşimi
# displot, histplot ve kdeplot'un birleşimi gibi çalışır. Farkı, facetgrid kullanarak birden fazla grafiği kolayca oluşturmaya imkan tanımasıdır.
#
# * kde=True → Histogram üzerine yoğunluk eğrisi ekler.
# * displot, ayrı bir Figure oluşturur ve FacetGrid yapısını destekler.

# %%
import seaborn as sns
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.displot(df.price, kde = False)
# bu kod price değişkeninin dağılımını gösterir. kde = False ile çizgiyi kaldırdık.

# %%
help(sns.displot)
# Out:
# Help on function displot in module seaborn.distributions:
#
# displot(data=None, *, x=None, y=None, hue=None, row=None, col=None, weights=None, kind='hist', rug=False, rug_kws=None, log_scale=None, legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, row_order=None, col_order=None, height=5, aspect=1, facet_kws=None, **kwargs)
#     Figure-level interface for drawing distribution plots onto a FacetGrid.
#
#     This function provides access to several approaches for visualizing the
#     univariate or bivariate distribution of data, including subsets of data
#     defined by semantic mapping and faceting across multiple subplots. The
#     ``kind`` parameter selects the approach to use:
#
#     - :func:`histplot` (with ``kind="hist"``; the default)
#     - :func:`kdeplot` (with ``kind="kde"``)
#     - :func:`ecdfplot` (with ``kind="ecdf"``; univariate-only)
#
#     Additionally, a :func:`rugplot` can be added to any kind of plot to show
# ...

# %%
sns.displot(df.price, bins = 1000, kde = False)

# %%
sns.displot(df.price, bins = 10, kde = False)

# %%
sns.displot(df.price, kde = True)
# bu kodun açıklaması : kde = True ile çizgiyi ekledik.

# %%
df["price"].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
sns.displot(df.price, kind="kde")
# Yoğunluk grafiği çizdik.

# %%
sns.kdeplot(df.price, shade = True)
# Yoğunluk grafiği çizdik. shade = True ile renklendirdik.
# Out:
# C:\Users\Kutay\AppData\Local\Temp\ipykernel_32732\2419399276.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.price, shade = True)
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ## Histogram ve YOğunluk Grafiği Çaprazlamaları

# %%
(sns
 .FacetGrid(df,
            hue = "cut",
            height = 5,
            xlim = (0,10000))
.map(sns.kdeplot, "price", shade= True)
.add_legend()
);

# cut değişkeni ile price değişkeninin yoğunluğunu karşılaştırdık.
# Out:
# c:\Users\Kutay\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\Kutay\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\Kutay\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\Kutay\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
sns.catplot(x = "cut", y = "price", hue = "color",kind="point",data = df)
# catplot ile kategorik değişkenlerin price değişkenine etkisini inceledik.
