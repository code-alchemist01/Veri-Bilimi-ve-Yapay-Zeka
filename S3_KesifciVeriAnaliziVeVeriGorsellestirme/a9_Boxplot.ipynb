# %% [markdown]
# # Boxplot

# %% [markdown]
# Boxplot, bir değişkenin dağılımını ve çeyrek değerlerini görselleştiren bir grafik türüdür. Veri setindeki uç değerleri (outliers) ve dağılımı anlamak için kullanılır.
#
# 📌 Boxplot'un Temel Bileşenleri
# * Medyan (Ortadaki Çizgi) → Verinin ortanca (median) değerini gösterir.
# * Kutunun Alt ve Üst Kenarı (Q1 ve Q3) → Verinin 1. çeyreği (Q1, %25'lik kısım) ve 3. çeyreği (Q3, %75'lik kısım) arasındaki dağılımı gösterir.
# * İç Çizgiler (Whiskers) → Q1 ve Q3'ten sonra verinin minimum ve maksimum değerlerini temsil eder (uç değerler hariç).
# * Uç Değerler (Outliers, Noktalar) → Normal dağılımdan sapmış, sıradışı verileri gösterir.

# %% [markdown]
# ### Veri Seti Hikayesi
#
# * total_bill: Yemeğin toplam fiyatı (bahşişler ve vergiler dahil)
# * tip: Bahşiş
# * sex: Ücreti ödeyen kişinin cinsiyeti(0=male, 1=female)
# * smoker: Grupta sigara içen var mı? (0=No, 1=Yes)
# * day: Gün (3=Thursday, 4=Friday, 5=Saturday, 6=Sunday)
# * time: Ne zaman? (0=Day, 1=Night)
# * size: grupta kaç kişi var?

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df["total_bill"].value_counts()
# Out:
# total_bill
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ### Görselleştirme

# %%
sns.boxplot(x=df["total_bill"])
# Bu kod mevcut total billin box grafiğini verir
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(y=df["total_bill"], orient="v")
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ### Kutu Grafik Çaprazlama

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
# Hangi günler daha fazla kazanç sağlanmış
sns.boxplot(x="day", y="total_bill", data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# sabah mı akşam mı daha fazla kazanç sağlanmış
sns.boxplot(x="time", y="total_bill", data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
# cinsiyete göre kazanç durumu
sns.boxplot(x="sex", y="total_bill", data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# kişi sayısına göre kazanç durumu
sns.boxplot(x="size", y="total_bill", data=df)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
# sigara içenlerin kazanç durumu
sns.boxplot(x="smoker", y="total_bill", data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# cinsiyete ve sigara içme durumuna göre kazanç durumu
sns.boxplot(x="sex", y="total_bill", hue="smoker", data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# gün ve cinsiye göre kazanç durumu
sns.boxplot(x="day", y="total_bill", hue="sex", data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin Grafiği

# %% [markdown]
# Violin plot, boxplot ile yoğunluk grafiğinin birleşimidir. Bir değişkenin dağılımını ve olasılık yoğunluğunu (density) gösterir.
#
# 📌 Violin Plot'un Temel Bileşenleri
# * Boxplot ile Benzer Çeyrekler (Q1, Q2, Q3) → Medyanı ve çeyrekleri içerir.
# * Kernel Density Estimation (Yoğunluk Eğrisi) → Verinin dağılımını gösterir.
# * Simetrik veya Asimetrik Olabilir → Normal dağılımda simetriktir, farklı yoğunluklarda asimetrik olabilir.

# %%
# Violin Grafiği
# Violin Grafiği, kutu grafiğine benzer bir görselleştirme tekniğidir. Dağılımın yoğunluğunu gösterir. Kutu grafiğe göre daha fazla bilgi sağlar.
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y="total_bill", kind="violin" , data=df)

# %% [markdown]
# #### Violin Çaprazlama

# %%
# cinsiyete göre kazanç durumu
sns.catplot(x="day", y="total_bill", kind="violin" , data=df)

# %%
# cinsiyete ve güne göre kazanç durumu
sns.catplot(x="day", y="total_bill",hue="sex", kind="violin" , data=df)
