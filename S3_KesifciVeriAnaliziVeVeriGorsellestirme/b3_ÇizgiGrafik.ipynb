# %% [markdown]
# # Çizgi Grafik
#
# * 📈 Çizgi Grafik (Line Plot) – sns.lineplot()
# Çizgi grafik, zaman serileri veya sürekli verilerdeki eğilimleri göstermek için kullanılır. Veri noktaları birleştirilerek değişim görselleştirilir.
#
# > 📌 Önemli Parametreler
# * x → X ekseni değişkeni (genellikle zaman)
# * y → Y ekseni değişkeni (ölçülen değer)
# * data → Kullanılan veri seti
# * marker → Her noktaya işaret koyar (örn: "o", "s", "D")
# * hue → Kategorik gruplara göre renkleri ayırır
# * style → Çizgi stilini ayırmak için kullanılır
# * palette → Renk paletini belirler

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
df["timepoint"].describe().T
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe().T
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe().T
# Out:
# timepoint         0          1          2          3          4          5   \
# count      56.000000  56.000000  56.000000  56.000000  56.000000  56.000000
# mean       -0.016662  -0.025002  -0.012873   0.034446   0.098194   0.137725
# std         0.028326   0.030641   0.035440   0.058260   0.092838   0.123353
# min        -0.064454  -0.082174  -0.110565  -0.089708  -0.046347  -0.017946
# 25%        -0.039169  -0.046299  -0.034944  -0.001157   0.030912   0.042762
# 50%        -0.018382  -0.024533  -0.013183   0.028430   0.070166   0.096535
# 75%         0.003539  -0.005388   0.009318   0.061840   0.144911   0.211638
# max         0.074399   0.063558   0.077277   0.185581   0.346775   0.476055
#
# timepoint         6          7          8          9          10         11  \
# count      56.000000  56.000000  56.000000  56.000000  56.000000  56.000000
# mean        0.127515   0.075660   0.013420  -0.032041  -0.053685  -0.058194
# ...

# %%
sns.lineplot(x = "timepoint", y = "signal", data = df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint", y = "signal", hue="event",data = df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint", y = "signal", hue="event",style="event",data = df)
# style parametresi ile event değişkenine göre çizgi stili belirlenir.
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint", 
             y = "signal", 
             hue="region",
             style="event",
             data = df)

# markers parametresi ile noktaları belirleriz. 
# dashes parametresi ile çizgileri belirleriz.
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ## Basit Zaman Serisi Grafiği
# * sns.lineplot()
#
# Zaman serisi grafikleri, belirli bir zaman diliminde değişen verileri görselleştirmek için kullanılır. Seaborn'da lineplot() fonksiyonu ile kolayca oluşturulabilir.
#
# > 📌 Önemli Noktalar:
# * date_range(start, periods, freq) → Belirtilen başlangıç tarihi ile zaman serisi oluşturur.
# * marker="o" → Her veri noktasını belirgin hale getirir.
# * xticks(rotation=45) → Tarih etiketlerini eğerek okunabilir yapar.
# * title, xlabel, ylabel → Grafik başlığı ve eksen adlandırmaları.

# %%
# !pip install pandas_datareader
# !pip install yfinance
import pandas_datareader as pdr

# %%
import yfinance as yf

# AAPL verilerini çek
df = yf.download("AAPL", start="2016-01-01", end="2019-08-25")
# hisse senedi verilerini çekmek için yfinance kütüphanesini kullanıyoruz.
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(df.head())
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04  23.834370  23.838895  23.076466  23.214473  270597600
# 2016-01-05  23.237106  23.947500  23.169235  23.924876  223164000
# 2016-01-06  22.782364  23.160186  22.594586  22.750690  273829600
# 2016-01-07  21.820841  22.653404  21.816317  22.325357  324377600
# 2016-01-08  21.936230  22.422646  21.890982  22.295952  283192000

# %%
df.shape
# Out:
# (917, 5)

# %%
kapanis = df["Close"]

# %%
kapanis.head()
# Out:
# Ticker           AAPL
# Date
# 2016-01-04  23.834370
# 2016-01-05  23.237106
# 2016-01-06  22.782364
# 2016-01-07  21.820841
# 2016-01-08  21.936230

# %%
kapanis.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
kapanis.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)

# %%
import pandas as pd
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.head()
# Out:
# Ticker           AAPL
# Date
# 2016-01-04  23.834370
# 2016-01-05  23.237106
# 2016-01-06  22.782364
# 2016-01-07  21.820841
# 2016-01-08  21.936230

# %%
kapanis.plot()
# Out:
# <Axes: xlabel='Date'>
